# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

# %%
data = pd.read_csv('USA_Housing.csv')
data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
print(data.describe())
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
data = data.drop(['Address'], axis=1)
data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Min-Max Scaling
scaler_minmax = MinMaxScaler()
X_minmax_scaled = scaler_minmax.fit_transform(X)

# Standardization
scaler_standard = StandardScaler()
X_standard_scaled = scaler_standard.fit_transform(X)

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Price'].dropna(), bins=30, kde=True)  # Drop any NaN values if they exist
plt.title('Shpërndarja e Çmimeve të Shtëpive')
plt.xlabel('Çmimi')
plt.ylabel('Frekuenca')
plt.show()

# %%
plt.figure(figsize=(12, 8))
correlation_matrix = data.corr()
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Matrica e Korrelacionit')
plt.show()

# %%
X = data.drop('Price', axis=1)
Y = data['Price']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.30)

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)

# %%
predictions
# Out:
# array([1335519.63975165, 1365737.85013821,  898735.06956654, ...,
#        1096782.00896823,  982869.33413348, 1159358.01709683])

# %%
error = np.sqrt(metrics.mean_absolute_error(Y_test, predictions))
error_decision_tree = np.sqrt(metrics.mean_absolute_error(Y_test, predicted_prices_decision_tree))

# %%
error
# Out:
# 283.3541316420437

# %%
random_forest_model = RandomForestRegressor()
random_forest_model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %%
predicted_prices_random_forest = random_forest_model.predict(X_test)

# %%
predicted_prices_random_forest
# Out:
# array([1352488.74235838, 1335617.25452047,  977192.53672126, ...,
#        1049677.81816318, 1036238.67310177, 1203099.51619445])

# %%
error_random_forest = np.sqrt(metrics.mean_absolute_error(Y_test, predicted_prices_random_forest))

# %%
error_random_forest
# Out:
# 306.80506002398437

# %%
random_forest_model = RandomForestRegressor()

# %%
decision_tree_model = DecisionTreeRegressor()
decision_tree_model.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor()

# %%
predicted_prices_decision_tree = decision_tree_model.predict(X_test)

# %%
predicted_prices_decision_tree
# Out:
# array([1363669.06891532, 1200539.36116778,  990893.16007157, ...,
#         873509.18952667, 1080624.49716572, 1240754.93204638])

# %%
error_decision_tree = np.sqrt(metrics.mean_absolute_error(Y_test, predicted_prices_decision_tree ))

# %%
error_decision_tree
# Out:
# 373.34902377073587
